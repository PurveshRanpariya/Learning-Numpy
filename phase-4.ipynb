# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1, 2, 3], [4, 5, 6]])
array2 = np.random.rand(3, 3)
array3 = np.zeros((4, 4))

# %%
np.save('array1.npy', array1)
np.save('array2.npy', array2)
np.save('array3.npy', array3)

# %%
loaded_array1 = np.load('array1.npy')
loaded_array2 = np.load('array2.npy')
print("Loaded Array 1:\n", loaded_array1)
print("Loaded Array 2:\n", loaded_array2)
# Out:
# Loaded Array 1:
#  [[1 2 3]
#  [4 5 6]]
# Loaded Array 2:
#  [[0.72527432 0.92580951 0.19476177]
#  [0.08371249 0.80026416 0.48144448]
#  [0.78733138 0.2418149  0.617588  ]]

# %%
# try:
#     logo = np.load('numpy-logo.npy')
    
#     #Display
#     plt.Figure(figsize=(10,5))
#     plt.subplots(121)
#     plt.imshow(logo)
#     plt.title("NumPy Logo")
#     plt.grid(False)
    
    
    
# except FileNotFoundError as e:
#     print("Error: File not found.", e)

import numpy as np
import matplotlib.pyplot as plt

try:
    # Load the numpy logo array
    logo = np.load("numpy-logo.npy")

    # Display as image
    plt.imshow(logo)
    plt.axis("off")  # hide axes
    plt.title("NumPy Logo")
    plt.show()
    
    dark_logo = 1 - logo  # Invert colors
    
    plt.imshow(dark_logo)
    plt.axis("off")  # hide axes

except FileNotFoundError as e:
    print("Error: File not found.", e)
